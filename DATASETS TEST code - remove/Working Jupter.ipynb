# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect
import codecs

# %%
csv_file = "master_data.csv"
df = pd.read_csv(csv_file, encoding='ISO-8859-1')

# %%
columns_to_keep = ['Reduxo ID','Fulcrum ID','Date', 'Latitude', 'Longitude','Site','Space','Level','Location Description','Asset Category','Asset Sub Category','Asset Type','GPS With Arrow','Parent QR Code','QR Code','Quantity','Condition','Photo 1']
df = df[columns_to_keep]
df.head()
# Out:
#   Reduxo ID                            Fulcrum ID        Date   Latitude  \
# 0  RSP00001  701826fa-75ef-4319-b110-9ee3e260b864  2021-12-21 -35.030741
# 1  RSP00002  72cfe468-8dcf-410d-8869-e0a7c6c9d85b  2021-12-21 -35.030744
# 2  RSP00003  6bb106d6-5a44-4b03-9cfe-2fc38c3a0bb9  2021-12-20 -35.030790
# 3  RSP00004  f75dceb1-e86d-44a3-a03a-34bc9def0145  2021-12-21 -35.030741
# 4  RSP00005  5a34d476-281c-41a2-8930-d4e513c3775c  2021-12-21 -35.030741
#
#     Longitude    Site           Space   Level Location Description  \
# 0  117.895305  Albany  Admin Building  Ground            Bike Shed
# 1  117.895318  Albany  Admin Building  Ground            Bike Shed
# 2  117.895312  Albany  Admin Building  Ground            Bike Shed
# 3  117.895305  Albany  Admin Building  Ground            Bike Shed
# 4  117.895305  Albany  Admin Building  Ground            Bike Shed
#
#          Asset Category Asset Sub Category                  Asset Type  \
# 0        Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 1  Furniture & Fittings          Furniture               Shelf Racking
# 2   IT & Communications                 IT                       Other
# 3     Kitchen Equipment      Refrigeration                     Freezer
# 4     Kitchen Equipment      Refrigeration  Refrigerator - Bar (Small)
#
#   GPS With Arrow Parent QR Code QR Code  Quantity Condition  \
# 0             No            NaN  102054         1  3 - Good
# 1             No            NaN     NaN         2  3 - Good
# 2             No            NaN  105865         1  3 - Good
# 3             No            NaN     NaN         1  3 - Good
# 4             No            NaN     NaN         1  3 - Good
#
#                             Photo 1
# 0                               NaN
# 1                               NaN
# 2  RSP00003_Q105865_20211220_01.jpg
# 3          RSP00004_20211221_01.jpg
# 4          RSP00005_20211221_01.jpg

# %%
df = df.loc[(df['Site'] == 'Esperance')]
df.head()
# Out:
#      Reduxo ID                            Fulcrum ID        Date   Latitude  \
# 3616  RSP03617  edd38823-03c7-461f-b0ce-104977999031  2021-11-23 -33.869417
# 3617  RSP03618  0065dcd3-452e-4d43-b927-3b987fc46f6e  2021-11-23 -33.869417
# 3618  RSP03619  850e850f-c99b-49ef-8790-37623241e0ab  2021-11-26 -33.872698
# 3619  RSP03620  8bae8a5c-5680-4259-8b9b-0f9aaad81fb8  2021-11-18 -33.873767
# 3620  RSP03621  97d91e0d-d3a6-4cca-a975-47af302688a0  2021-11-18 -33.873767
#
#        Longitude       Site     Space   Level Location Description  \
# 3616  121.894458  Esperance   01SMV45  Ground             External
# 3617  121.894458  Esperance   01SMV45  Ground                  NaN
# 3618  121.899853  Esperance   02SMV16  Ground                  NaN
# 3619  121.902326  Esperance  1TVS 337  Ground              Trailer
# 3620  121.902326  Esperance  1TVS 337  Ground              Trailer
#
#       Asset Category Asset Sub Category                  Asset Type  \
# 3616   Port Specific           Conveyer     Emergency Stop (button)
# 3617  Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 3618  Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 3619  Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 3620   Port Specific           Conveyer     Emergency Stop (button)
#
#      GPS With Arrow Parent QR Code QR Code  Quantity Condition  \
# 3616             No         107519  103311         1  3 - Good
# 3617             No         107519  103744         1  3 - Good
# 3618             No         107522  103886         1  3 - Good
# 3619             No         107323  103239         1  3 - Good
# 3620             No         107323  103240         1  3 - Good
#
#                                Photo 1
# 3616  RSP03617_Q103311_20211123_01.jpg
# 3617                               NaN
# 3618                               NaN
# 3619  RSP03620_Q103239_20211118_01.jpg
# 3620  RSP03621_Q103240_20211118_01.jpg

# %%
new_df = df.groupby('Space').head(5).reset_index(drop=True)

# %%
new_df['Condition Ranking'] = new_df['Condition'].str.strip().str[-4:]
new_df['Condition Point'] = new_df['Condition'].str.strip().str[:1]
new_df.head()
# Out:
#   Reduxo ID                            Fulcrum ID        Date   Latitude  \
# 0  RSP03617  edd38823-03c7-461f-b0ce-104977999031  2021-11-23 -33.869417
# 1  RSP03618  0065dcd3-452e-4d43-b927-3b987fc46f6e  2021-11-23 -33.869417
# 2  RSP03619  850e850f-c99b-49ef-8790-37623241e0ab  2021-11-26 -33.872698
# 3  RSP03620  8bae8a5c-5680-4259-8b9b-0f9aaad81fb8  2021-11-18 -33.873767
# 4  RSP03621  97d91e0d-d3a6-4cca-a975-47af302688a0  2021-11-18 -33.873767
#
#     Longitude       Site     Space   Level Location Description  \
# 0  121.894458  Esperance   01SMV45  Ground             External
# 1  121.894458  Esperance   01SMV45  Ground                  NaN
# 2  121.899853  Esperance   02SMV16  Ground                  NaN
# 3  121.902326  Esperance  1TVS 337  Ground              Trailer
# 4  121.902326  Esperance  1TVS 337  Ground              Trailer
#
#    Asset Category Asset Sub Category                  Asset Type  \
# 0   Port Specific           Conveyer     Emergency Stop (button)
# 1  Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 2  Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 3  Fire Equipment   Fire Suppression  Portable Fire Extinguisher
# 4   Port Specific           Conveyer     Emergency Stop (button)
#
#   GPS With Arrow Parent QR Code QR Code  Quantity Condition  \
# 0             No         107519  103311         1  3 - Good
# 1             No         107519  103744         1  3 - Good
# 2             No         107522  103886         1  3 - Good
# 3             No         107323  103239         1  3 - Good
# 4             No         107323  103240         1  3 - Good
#
#                             Photo 1 Condition Ranking Condition Point
# 0  RSP03617_Q103311_20211123_01.jpg              Good               3
# 1                               NaN              Good               3
# 2                               NaN              Good               3
# 3  RSP03620_Q103239_20211118_01.jpg              Good               3
# 4  RSP03621_Q103240_20211118_01.jpg              Good               3

# %%
with codecs.open('new_master_data.csv', 'w', encoding='utf-8') as f:
    new_df.to_csv(f, index=False)

# %%
new_df.to_json('new_master_data.json', orient='records')
